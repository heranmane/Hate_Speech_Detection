# %%
from twarc import Twarc2, expansions
import datetime
import json
import pandas as pd

# %%
# Replace your bearer token below
client = Twarc2(bearer_token="AAAAAAAAAAAAAAAAAAAAAFRnQQEAAAAAFh2zB4ZgnDRjW7DOWutPyAGLu7k%3Dq47v6wTyUrYjWa8rK6Qi1JYVgUzA2kJEpu4G5IEVCoPzwzElAQ")

# %%
def main():
#     # Specify the start time in UTC for the time period you want replies from
    start_time = datetime.datetime(2020, 1, 1, 0, 0, 0, 0, datetime.timezone.utc)

#     # Specify the end time in UTC for the time period you want Tweets from
    end_time = datetime.datetime(2020, 12, 31, 0, 0, 0, 0, datetime.timezone.utc)

    # This is where we specify our query as discussed in module 5
    query = ("from:twitterdev has:geo")

    # Name and path of the file where you want the Tweets written to
    file_name = '2020_tweet.json'
    

    # The search_all method call the full-archive search endpoint to get Tweets based on the query, start and end times
    search_results = client.search_all(query=query, start_time=start_time, end_time=end_time,)

    # Twarc returns all Tweets for the criteria set above, so we page through the results
    for page in search_results:
        # The Twitter API v2 returns the Tweet information and the user, media etc.  separately
        # so we use expansions.flatten to get all the information in a single JSON
        result = expansions.flatten(page)
        # We will open the file and append one JSON object per new line
        with open(file_name, 'a+') as filehandle:
            for tweet in result:
                filehandle.write('%s\n' % json.dumps(tweet))


if __name__ == "__main__":
    main()

# %%
df = pd.read_json(open("2020_tweet.json", "r", encoding="utf8"),lines=True)
df.shape
# Out:
# (397, 18)

# %%
df.head()
# Out:
#                                                 text                   id  \
# 0  If you've ever used Twitter's publisher tools,...  1398361598062854144
# 1  Weekend [code] warriors unite!\n\nStart with S...  1398330436305121280
# 2  What happens when devs feel artsy...🎨 #BuildWh...  1397993874254008320
# 3  The Twitter Developer Platform. Ooh la la! htt...  1397568983931392000
# 4  Want a quick and easy reference for writing se...  1397253448538607616
#
#                                             entities  possibly_sensitive  \
# 0  {'annotations': [{'start': 20, 'end': 26, 'pro...               False
# 1  {'urls': [{'start': 66, 'end': 89, 'url': 'htt...               False
# 2  {'urls': [{'start': 78, 'end': 101, 'url': 'ht...               False
# 3  {'annotations': [{'start': 4, 'end': 10, 'prob...               False
# 4  {'urls': [{'start': 127, 'end': 150, 'url': 'h...               False
#
#                                       public_metrics      conversation_id  \
# ...

# %%
tweet_df = pd.DataFrame(df)
tweet_df.to_csv('tweetss.csv')

# %%
tw_df =pd.read_csv('tweetss.csv')

# %%
print(tw_df['text'], end='\n') 
# for tweet in tweets:
#     if 'text' in tweet.keys()

# %%
import requests
import os
import json

# %%
# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
bearer_token = os.environ.get("AAAAAAAAAAAAAAAAAAAAAFRnQQEAAAAAFh2zB4ZgnDRjW7DOWutPyAGLu7k%3Dq47v6wTyUrYjWa8rK6Qi1JYVgUzA2kJEpu4G5IEVCoPzwzElAQ")

search_url = "https://api.twitter.com/2/tweets/search/all"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
query_params = {'query': '(from:twitterdev)','tweet.fields': 'author_id'}


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers
    print(headers)


# def connect_to_endpoint(url, headers, params):
#     response = requests.request("GET", search_url, headers=headers, params=params)
#     print(response.status_code)
#     if response.status_code != 200:
#         raise Exception(response.status_code, response.text)
#     return response.json()


# def main():
#     headers = create_headers(bearer_token)
#     json_response = connect_to_endpoint(search_url, headers, query_params)
#     print(json.dumps(json_response, indent=4, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 401
# null
